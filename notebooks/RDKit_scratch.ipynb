# %%
from rdkit import Chem
from rdkit.Chem import Draw

m = Chem.MolFromMolFile('Nicolaioidesin A.sdf')
display(Draw.MolToImage(m))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 4
#       1 from rdkit import Chem
#       2 from rdkit.Chem import Draw
# ----> 4 m = Chem.MolFromMolFile('Nicolaioidesin A.sdf')
#       5 display(Draw.MolToImage(m))
#
# OSError: Bad input file Nicolaioidesin A.sdf

# %%
print(Chem.MolToSmiles(m))
# Out:
# COc1cc(O)c(C(=O)C2C(CC=C(C)C)C(C)=CCC2c2ccccc2)c(O)c1

# %%
m2 = Chem.MolFromSmiles('CC1=C[C@@H](c2cc([C@@H]3Oc4cc(O)ccc4C(=O)[C@H]3O)c(O)cc2)[C@H](C(=O)c2ccc(O)cc2O)[C@@H](c2ccc(O)cc2O)C1')
# Chem.SanitizeMol(m2)
display(Draw.MolToImage(m2))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
m1 = Chem.MolFromSmiles("Oc1cc2#c(C(C(c3ccc(O)cc3)=CO2)=O)cc1")
Chem.SanitizeMol(m1)
print(Chem.MolToSmiles(m1))
# Out:
# [21:43:47] Explicit valence for atom # 3 C, 6, is greater than permitted
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[4], line 2
#       1 m1 = Chem.MolFromSmiles("Oc1cc2#c(C(C(c3ccc(O)cc3)=CO2)=O)cc1")
# ----> 2 Chem.SanitizeMol(m1)
#       3 print(Chem.MolToSmiles(m1))
#
# ArgumentError: Python argument types in
#     rdkit.Chem.rdmolops.SanitizeMol(NoneType)
# did not match C++ signature:
#     SanitizeMol(RDKit::ROMol {lvalue} mol, unsigned long sanitizeOps=rdkit.Chem.rdmolops.SanitizeFlags.SANITIZE_ALL, bool catchErrors=False)
