# %%
from aizynthfinder.interfaces import AiZynthApp
app = AiZynthApp("data/config.yml")
# Out:
# Loading template-based expansion policy model from /home/ljx/retro_synthesis/data/uspto_model.onnx to uspto
# Loading templates from /home/ljx/retro_synthesis/data/uspto_templates.csv.gz to uspto
# Loading template-based expansion policy model from /home/ljx/retro_synthesis/data/uspto_ringbreaker_model.onnx to ringbreaker
# Loading templates from /home/ljx/retro_synthesis/data/uspto_ringbreaker_templates.csv.gz to ringbreaker
# Loading filter policy model from /home/ljx/retro_synthesis/data/uspto_filter_model.onnx to uspto
# Loading stock from InMemoryInchiKeyQuery to zinc
# Text(value='', continuous_update=False, description='SMILES')
# Output(layout=Layout(border='1px solid silver', height='180px', width='50%'))
# HBox(children=(VBox(children=(Label(value='Stocks'), Checkbox(value=True, description='zinc', style=Descriptio…
# HBox(children=(Button(description='Run Search', style=ButtonStyle()), Button(description='Extend Search', styl…
# Output(layout=Layout(border='1px solid silver', height='320px', overflow='auto', width='99%'))
# HBox(children=(Button(description='Show Routes', style=ButtonStyle()), Dropdown(description='Routes: ', disabl…
# Output(layout=Layout(border='1px solid silver', overflow='auto', width='99%'))
# Output(layout=Layout(border='1px solid silver', width='99%'))

# %%
# %matplotlib inline
from aizynthfinder.interfaces.gui.clustering import ClusteringGui
ClusteringGui.from_app(app)
# Out:
# Output(layout=Layout(height='310px', overflow_y='auto', width='99%'))
# HBox(children=(Label(value='Number of clusters to make'), BoundedIntText(value=1, continuous_update=True, layo…
# Output()
# Tab()
